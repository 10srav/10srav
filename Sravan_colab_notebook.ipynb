# %% [markdown]
# <a href="https://colab.research.google.com/github/10srav/10srav/blob/main/Sravan_colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FMML tech member

# %%
import math
num=7
factorial=math.factorial(num)
print(factorial)
# Out:
# 5040
